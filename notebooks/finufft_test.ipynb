# %%
from StellarRadioAlgorithm import StellarRadioAlg

# %%
run_run = StellarRadioAlg()
run_run.run_all_steps()
# Out:
# WARNING: AstropyDeprecationWarning: The update_default_config function is deprecated and may be removed in a future version. [astroquery._astropy_init]
# Frequency guess: 14.187637075855344
# Iteration 0
# Amps: 2000.0 1285.83538482371
# Phases: -1.0 -1.1479568369279758
# Frequencies: 14.187637075855344 14.187639781932361
# Iteration 1
# Amps: 1285.83538482371 1285.8354883571571
# Phases: -1.1479568369279758 -1.1334329689980733
# Frequencies: 14.187639781932361 14.187641134971129
# Iteration 2
# Amps: 1285.8354883571571 1285.8355403231253
# Phases: -1.1334329689980733 -1.1261710775426963
# Frequencies: 14.187641134971129 14.187639781932234
# Iteration 3
# Amps: 1285.8355403231253 1285.8354883571722
# Phases: -1.1261710775426963 -1.1334329696758447
# Frequencies: 14.187639781932234 14.187641134971
